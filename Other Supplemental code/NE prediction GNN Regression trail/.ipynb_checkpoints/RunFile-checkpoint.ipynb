# %%
# %matplotlib inline

# %% [markdown]
# ## Mathmatic Functions

# %%
def N_Result(N):
    (max_pred,min_pred) = pred(N,converted_dict,converted_dict1,converted_dict2) 

    max_suc_count = 0
    min_suc_count = 0
    if v1 in max_pred:
        max_suc_count +=1
    if v2 in min_pred:
        min_suc_count +=1   
    
    return(max_suc_count,min_suc_count)

# %%
# %run excute-nonZS-MaxMin.ipynb
max_suc_count_1 = 0
min_suc_count_1 = 0
max_suc_count_2 = 0
min_suc_count_2 = 0
max_suc_count_3 = 0
min_suc_count_3 = 0
max_suc_count_4 = 0
min_suc_count_4 = 0
max_suc_count_5 = 0
min_suc_count_5 = 0
pred_errors = []
for i in range(1,101): #create 100 random network
    print("Expriment "+str(i))
    (v1,v2, max_opinion, min_opinion,max_pol, s, G, a,b,c,d) = run(n)  #collect ground-truth result
    #(max,min,degree_rank,closeness_Rank,eigen_rank,op_rank)
    
    for N in range(1,6):#compare truth and prediction, as prediction scale goes up
        if N == 1:
            (max_pred, min_pred) = pred(N,a,b,c,d)
            dif = pred_error(s, G, max_pol, v1, min_pred[0])
            if v1 in max_pred:
                max_suc_count_1 +=1
            if v2 in min_pred:
                min_suc_count_1 +=1       
            
#             print(max_suc_count_1,min_suc_count_1)
        if N == 2:
            (max_pred, min_pred) = pred(N,a,b,c,d)
            if v1 in max_pred:
                max_suc_count_2 +=1
            if v2 in min_pred:
                min_suc_count_2 +=1 
            print(max_suc_count_2,min_suc_count_2)
                
        if N == 3:
            (max_pred, min_pred) = pred(N,a,b,c,d)
            if v1 in max_pred:
                max_suc_count_3 +=1
            if v2 in min_pred:
                min_suc_count_3 +=1 
            print(max_suc_count_3,min_suc_count_3)
                
        if N == 4:
            (max_pred, min_pred) = pred(N,a,b,c,d)
            if v1 in max_pred:
                max_suc_count_4 +=1
            if v2 in min_pred:
                min_suc_count_4 +=1 
            print(max_suc_count_4,min_suc_count_4)
                
        if N == 5:
            (max_pred, min_pred) = pred(N,a,b,c,d)
            if v1 in max_pred:
                max_suc_count_5 +=1
            if v2 in min_pred:
                min_suc_count_5 +=1 
            print(max_suc_count_5,min_suc_count_5)
  
    pred_errors.append(dif)  

error_perc = abs(np.mean(pred_errors)/max_pol)*100
print("the average polarization difference in predid and actual:"+str(np.mean(pred_errors)))
print("error % is:"+str(error_perc)+str("%"))
# Out:
# Expriment 1
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.18114348024443483 changed to 1
# Min Action:    Agent17 's opinion 0.1519655238548644 changed to 0.8640734318177643
# Network reaches equilibrium Polarization: 0.04186389794186749
# Min limited by K is : [12]
# Max limited by K is : [19]
# difference in prediction:0.01030495477483101
# Min limited by K is : [12]
# Max limited by K is : [19, 18]
# 1 0
# Min limited by K is : [12]
# Max limited by K is : [19, 18, 17]
# 1 0
# Min limited by K is : [12]
# Max limited by K is : [19, 18, 17, 16]
# 1 0
# Min limited by K is : [12]
# Max limited by K is : [19, 18, 17, 16, 11]
# 1 0
# Expriment 2
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.7406380850803929 changed to 1
# Min Action:    Agent18 's opinion 0.11918727173161958 changed to 0.6410364355576729
# Network reaches equilibrium Polarization: 0.03603650470101887
# Min limited by K is : [3]
# Max limited by K is : [19]
# difference in prediction:0.008543638926118008
# Min limited by K is : [3]
# Max limited by K is : [19, 17]
# 2 0
# Min limited by K is : [3]
# Max limited by K is : [19, 17, 18]
# 2 0
# Min limited by K is : [3]
# Max limited by K is : [19, 17, 18, 2]
# 2 0
# Min limited by K is : [3]
# Max limited by K is : [19, 17, 18, 2, 16]
# 2 0
# Expriment 3
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.3048920293735754 changed to 0
# Min Action:    Agent6 's opinion 0.9713511834644578 changed to 0
# Network reaches equilibrium Polarization: 0.2554635038814148
# Min limited by K is : [6]
# Max limited by K is : [19]
# difference in prediction:0.02775015643416273
# Min limited by K is : [6]
# Max limited by K is : [19, 18]
# 3 1
# Min limited by K is : [6]
# Max limited by K is : [19, 18, 17]
# 3 1
# Min limited by K is : [6]
# Max limited by K is : [19, 18, 17, 15]
# 3 1
# Min limited by K is : [6]
# Max limited by K is : [19, 18, 17, 15, 14]
# 3 1
# Expriment 4
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.8564397330238807 changed to 1
# Min Action:    Agent16 's opinion 0.12445127432435876 changed to 1
# Network reaches equilibrium Polarization: 0.07289232701071675
# Min limited by K is : [6]
# Max limited by K is : [19]
# difference in prediction:0.01935254210591851
# Min limited by K is : [6]
# Max limited by K is : [19, 17]
# 4 1
# Min limited by K is : [6]
# Max limited by K is : [19, 17, 18]
# 4 1
# Min limited by K is : [6]
# Max limited by K is : [19, 17, 18, 1]
# 4 1
# Min limited by K is : [6]
# Max limited by K is : [19, 17, 18, 1, 14]
# 4 1
# Expriment 5
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.19148807330225082 changed to 0
# Min Action:    Agent6 's opinion 0.9795095785582183 changed to 0
# Network reaches equilibrium Polarization: 0.2278846562194524
# Min limited by K is : [0]
# Max limited by K is : [19]
# difference in prediction:0.024794210037129366
# Min limited by K is : [0]
# Max limited by K is : [19, 18]
# 5 1
# Min limited by K is : [0]
# Max limited by K is : [19, 18, 15]
# 5 1
# Min limited by K is : [0]
# Max limited by K is : [19, 18, 15, 17]
# 5 1
# Min limited by K is : [0]
# Max limited by K is : [19, 18, 15, 17, 3]
# 5 1
# Expriment 6
# C:\Users\xzhan176\AppData\Local\Temp\ipykernel_4684\1621945027.py:44: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   G = nx.adjacency_matrix(nxG).todense()
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.2859515505810015 changed to 0
# Min Action:    Agent18 's opinion 0.08877590131168234 changed to 0.7017558065289129
# Network reaches equilibrium Polarization: 0.031136637569437985
# Min limited by K is : [13]
# Max limited by K is : [18]
# difference in prediction:0.008940960413382097
# Min limited by K is : [13]
# Max limited by K is : [18, 19]
# 6 1
# Min limited by K is : [13]
# Max limited by K is : [18, 19, 17]
# 6 1
# Min limited by K is : [13]
# Max limited by K is : [18, 19, 17, 11]
# 6 1
# Min limited by K is : [13]
# Max limited by K is : [18, 19, 17, 11, 13]
# 6 1
# Expriment 7
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.04487046801346284 changed to 1
# Min Action:    Agent8 's opinion 0.9433883114132863 changed to 0
# Network reaches equilibrium Polarization: 0.03828209722328245
# Min limited by K is : [14]
# Max limited by K is : [19]
# difference in prediction:0.005666784429329802
# Min limited by K is : [14]
# Max limited by K is : [19, 18]
# 7 1
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17]
# 7 1
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16]
# 7 1
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16, 0]
# 7 1
# Expriment 8
#
# Maximizer finds its target agent:
# Max Action:    Agent16 's opinion 0.4691550171525173 changed to 0
# Min Action:    Agent11 's opinion 0.6914064226819019 changed to 0
# Network reaches equilibrium Polarization: 0.02286256641328569
# Min limited by K is : [6]
# Max limited by K is : [19]
# difference in prediction:0.0028036274087153076
# Min limited by K is : [6]
# Max limited by K is : [19, 16]
# 8 1
# Min limited by K is : [6]
# Max limited by K is : [19, 16, 17]
# 8 1
# Min limited by K is : [6]
# Max limited by K is : [19, 16, 17, 18]
# 8 1
# Min limited by K is : [6]
# Max limited by K is : [19, 16, 17, 18, 15]
# 8 1
# Expriment 9
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.617584536469046 changed to 0
# Min Action:    Agent2 's opinion 0.9107630615917967 changed to 0.34520324588532897
# Network reaches equilibrium Polarization: 0.02234237254265007
# Min limited by K is : [15]
# Max limited by K is : [19]
# difference in prediction:0.003129703727303791
# Min limited by K is : [15]
# Max limited by K is : [19, 18]
# 9 1
# Min limited by K is : [15]
# Max limited by K is : [19, 18, 16]
# 9 1
# Min limited by K is : [15]
# Max limited by K is : [19, 18, 16, 17]
# 9 1
# Min limited by K is : [15]
# Max limited by K is : [19, 18, 16, 17, 0]
# 9 1
# Expriment 10
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.10236993181477816 changed to 1
# Min Action:    Agent12 's opinion 0.11893404074966929 changed to 0.7816527568791387
# Network reaches equilibrium Polarization: 0.024298540211583897
# Min limited by K is : [14]
# Max limited by K is : [19]
# difference in prediction:0.0066188085899476605
# Min limited by K is : [14]
# Max limited by K is : [19, 17]
# 10 1
# Min limited by K is : [14]
# Max limited by K is : [19, 17, 18]
# 10 1
# Min limited by K is : [14]
# Max limited by K is : [19, 17, 18, 12]
# 10 1
# Min limited by K is : [14]
# Max limited by K is : [19, 17, 18, 12, 14]
# 10 1
# Expriment 11
#
# Maximizer finds its target agent:
# Max Action:    Agent17 's opinion 0.344139472069212 changed to 0
# Min Action:    Agent10 's opinion 0.9671683933557087 changed to 0
# Network reaches equilibrium Polarization: 0.03167815934297554
# Min limited by K is : [10]
# Max limited by K is : [17]
# difference in prediction:0.002979948604573214
# Min limited by K is : [10]
# Max limited by K is : [17, 19]
# 11 2
# Min limited by K is : [10]
# Max limited by K is : [17, 19, 18]
# 11 2
# Min limited by K is : [10]
# Max limited by K is : [17, 19, 18, 16]
# 11 2
# Min limited by K is : [10]
# Max limited by K is : [17, 19, 18, 16, 0]
# 11 2
# Expriment 12
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.2771249814507397 changed to 1
# Min Action:    Agent8 's opinion 0.04690235130484499 changed to 1
# Network reaches equilibrium Polarization: 0.05291946064502171
# Min limited by K is : [1]
# Max limited by K is : [19]
# difference in prediction:0.017922497820256116
# Min limited by K is : [1]
# Max limited by K is : [19, 18]
# 12 2
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 17]
# 12 2
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 17, 16]
# 12 2
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 17, 16, 12]
# 12 2
# Expriment 13
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.929886241828325 changed to 1
# Min Action:    Agent11 's opinion 0.04433968281809053 changed to 1
# Network reaches equilibrium Polarization: 0.232492140948714
# Min limited by K is : [13]
# Max limited by K is : [19]
# difference in prediction:0.06718251372851136
# Min limited by K is : [13]
# Max limited by K is : [19, 17]
# 13 2
# Min limited by K is : [13]
# Max limited by K is : [19, 17, 18]
# 13 2
# Min limited by K is : [13]
# Max limited by K is : [19, 17, 18, 16]
# 13 2
# Min limited by K is : [13]
# Max limited by K is : [19, 17, 18, 16, 14]
# 13 2
# Expriment 14
#
# Maximizer finds its target agent:
# Max Action:    Agent18 's opinion 0.8099618714211905 changed to 0
# Min Action:    Agent19 's opinion 0.3194851543188738 changed to 0.8952424317901305
# Network reaches equilibrium Polarization: 0.03623140566928908
# Min limited by K is : [0]
# Max limited by K is : [18]
# difference in prediction:0.006484169032005022
# Min limited by K is : [0]
# Max limited by K is : [18, 19]
# 14 2
# Min limited by K is : [0]
# Max limited by K is : [18, 19, 16]
# 14 2
# Min limited by K is : [0]
# Max limited by K is : [18, 19, 16, 17]
# 14 2
# Min limited by K is : [0]
# Max limited by K is : [18, 19, 16, 17, 15]
# 14 2
# Expriment 15
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5144840769989832 changed to 1
# Min Action:    Agent3 's opinion 0.008127511632615825 changed to 1
# Network reaches equilibrium Polarization: 0.04771498336582952
# Min limited by K is : [10]
# Max limited by K is : [19]
# difference in prediction:0.01860319280109543
# Min limited by K is : [10]
# Max limited by K is : [19, 16]
# 15 2
# Min limited by K is : [10]
# Max limited by K is : [19, 16, 18]
# 15 2
# Min limited by K is : [10]
# Max limited by K is : [19, 16, 18, 17]
# 15 2
# Min limited by K is : [10]
# Max limited by K is : [19, 16, 18, 17, 13]
# 15 2
# Expriment 16
#
# Maximizer finds its target agent:
# Max Action:    Agent17 's opinion 0.47822844969264133 changed to 1
# Min Action:    Agent5 's opinion 0.0061845576522960855 changed to 0.6400322427284553
# Network reaches equilibrium Polarization: 0.020724059054135872
# Min limited by K is : [12]
# Max limited by K is : [19]
# difference in prediction:0.0038940658736631925
# Min limited by K is : [12]
# Max limited by K is : [19, 17]
# 16 2
# Min limited by K is : [12]
# Max limited by K is : [19, 17, 18]
# 16 2
# Min limited by K is : [12]
# Max limited by K is : [19, 17, 18, 16]
# 16 2
# Min limited by K is : [12]
# Max limited by K is : [19, 17, 18, 16, 14]
# 16 2
# Expriment 17
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5435824111350971 changed to 1
# Min Action:    Agent13 's opinion 0.7682166051705687 changed to 0.00012641847140901861
# Network reaches equilibrium Polarization: 0.04595141224495986
# Min limited by K is : [5]
# Max limited by K is : [19]
# difference in prediction:0.010227321122046537
# Min limited by K is : [5]
# Max limited by K is : [19, 18]
# 17 2
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 17]
# 17 2
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 17, 16]
# 17 2
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 17, 16, 12]
# 17 2
# Expriment 18
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.38435598336618826 changed to 1
# Min Action:    Agent18 's opinion 0.6303129020601848 changed to 0
# Network reaches equilibrium Polarization: 0.07444554502344325
# Min limited by K is : [10]
# Max limited by K is : [19]
# difference in prediction:0.10474446519485903
# Min limited by K is : [10]
# Max limited by K is : [19, 18]
# 18 2
# Min limited by K is : [10]
# Max limited by K is : [19, 18, 17]
# 18 2
# Min limited by K is : [10]
# Max limited by K is : [19, 18, 17, 16]
# 18 2
# Min limited by K is : [10]
# Max limited by K is : [19, 18, 17, 16, 15]
# 18 2
# Expriment 19
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.9361307362440485 changed to 0
# Min Action:    Agent1 's opinion 0.9741745404204799 changed to 0.025155996794487323
# Network reaches equilibrium Polarization: 0.03796418156012613
# Min limited by K is : [1]
# Max limited by K is : [19]
# difference in prediction:0.003218954809889367
# Min limited by K is : [1]
# Max limited by K is : [19, 17]
# 19 3
# Min limited by K is : [1]
# Max limited by K is : [19, 17, 18]
# 19 3
# Min limited by K is : [1]
# Max limited by K is : [19, 17, 18, 16]
# 19 3
# Min limited by K is : [1]
# Max limited by K is : [19, 17, 18, 16, 14]
# 19 3
# Expriment 20
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.9084519411691975 changed to 0
# Min Action:    Agent18 's opinion 0.019984753077756934 changed to 1
# Network reaches equilibrium Polarization: 0.0615074318054146
# Min limited by K is : [0]
# Max limited by K is : [19]
# difference in prediction:0.04287545796112992
# Min limited by K is : [0]
# Max limited by K is : [19, 18]
# 20 3
# Min limited by K is : [0]
# Max limited by K is : [19, 18, 17]
# 20 3
# Min limited by K is : [0]
# Max limited by K is : [19, 18, 17, 15]
# 20 3
# Min limited by K is : [0]
# Max limited by K is : [19, 18, 17, 15, 16]
# 20 3
# Expriment 21
#
# Maximizer finds its target agent:
# Max Action:    Agent18 's opinion 0.08938658113033093 changed to 0
# Min Action:    Agent19 's opinion 0.9907285967734837 changed to 0.39715531561992906
# Network reaches equilibrium Polarization: 0.08209071424600475
# Min limited by K is : [19]
# Max limited by K is : [18]
# difference in prediction:0.0022590487248145275
# Min limited by K is : [19]
# Max limited by K is : [18, 19]
# 21 4
# Min limited by K is : [19]
# Max limited by K is : [18, 19, 7]
# 21 4
# Min limited by K is : [19]
# Max limited by K is : [18, 19, 7, 17]
# 21 4
# Min limited by K is : [19]
# Max limited by K is : [18, 19, 7, 17, 15]
# 21 4
# Expriment 22
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.7064742823439721 changed to 0
# Min Action:    Agent6 's opinion 0.9186012401617322 changed to 0.1031053591230046
# Network reaches equilibrium Polarization: 0.025359884464860556
# Min limited by K is : [3]
# Max limited by K is : [19]
# difference in prediction:0.0012212620485907155
# Min limited by K is : [3]
# Max limited by K is : [19, 16]
# 22 4
# Min limited by K is : [3]
# Max limited by K is : [19, 16, 18]
# 22 4
# Min limited by K is : [3]
# Max limited by K is : [19, 16, 18, 14]
# 22 4
# Min limited by K is : [3]
# Max limited by K is : [19, 16, 18, 14, 0]
# 22 4
# Expriment 23
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.4476657052156332 changed to 1
# Min Action:    Agent1 's opinion 0.07014946007596012 changed to 0.8649989915306813
# Network reaches equilibrium Polarization: 0.04072122744793044
# Min limited by K is : [15]
# Max limited by K is : [19]
# difference in prediction:0.010903675137709484
# Min limited by K is : [15]
# Max limited by K is : [19, 17]
# 23 4
# Min limited by K is : [15]
# Max limited by K is : [19, 17, 18]
# 23 4
# Min limited by K is : [15]
# Max limited by K is : [19, 17, 18, 16]
# 23 4
# Min limited by K is : [15]
# Max limited by K is : [19, 17, 18, 16, 1]
# 23 4
# Expriment 24
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.019908564884999702 changed to 1
# Min Action:    Agent18 's opinion 0.9960325875301104 changed to 0.27644801082526516
# Network reaches equilibrium Polarization: 0.031213009997503705
# Min limited by K is : [18]
# Max limited by K is : [19]
# difference in prediction:0.0010705295769485104
# Min limited by K is : [18]
# Max limited by K is : [19, 18]
# 24 5
# Min limited by K is : [18]
# Max limited by K is : [19, 18, 17]
# 24 5
# Min limited by K is : [18]
# Max limited by K is : [19, 18, 17, 16]
# 24 5
# Min limited by K is : [18]
# Max limited by K is : [19, 18, 17, 16, 15]
# 24 5
# Expriment 25
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.2274974988965388 changed to 1
# Min Action:    Agent3 's opinion 0.2415671260567701 changed to 1
# Network reaches equilibrium Polarization: 0.03032031753235761
# Min limited by K is : [14]
# Max limited by K is : [19]
# difference in prediction:0.01141239155492569
# Min limited by K is : [14]
# Max limited by K is : [19, 18]
# 25 5
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17]
# 25 5
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16]
# 25 5
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16, 15]
# 25 5
# Expriment 26
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5948938160549189 changed to 1
# Min Action:    Agent10 's opinion 0.06384388245707517 changed to 1
# Network reaches equilibrium Polarization: 0.07712416980157014
# Min limited by K is : [2]
# Max limited by K is : [19]
# difference in prediction:0.017124629043198822
# Min limited by K is : [2]
# Max limited by K is : [19, 15]
# 26 5
# Min limited by K is : [2]
# Max limited by K is : [19, 15, 18]
# 26 5
# Min limited by K is : [2]
# Max limited by K is : [19, 15, 18, 16]
# 26 5
# Min limited by K is : [2]
# Max limited by K is : [19, 15, 18, 16, 13]
# 26 5
# Expriment 27
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.8176866461112826 changed to 1
# Min Action:    Agent18 's opinion 0.8639865726296921 changed to 0.16784155346092153
# Network reaches equilibrium Polarization: 0.04282260931196455
# Min limited by K is : [2]
# Max limited by K is : [19]
# difference in prediction:0.02451356202015398
# Min limited by K is : [2]
# Max limited by K is : [19, 18]
# 27 5
# Min limited by K is : [2]
# Max limited by K is : [19, 18, 17]
# 27 5
# Min limited by K is : [2]
# Max limited by K is : [19, 18, 17, 16]
# 27 5
# Min limited by K is : [2]
# Max limited by K is : [19, 18, 17, 16, 15]
# 27 5
# Expriment 28
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.9922049042619533 changed to 1
# Min Action:    Agent18 's opinion 0.9678731821957247 changed to 0.2188715880713589
# Network reaches equilibrium Polarization: 0.03306419255370159
# Min limited by K is : [8]
# Max limited by K is : [19]
# difference in prediction:0.010546264415183429
# Min limited by K is : [8]
# Max limited by K is : [19, 17]
# 28 5
# Min limited by K is : [8]
# Max limited by K is : [19, 17, 18]
# 28 5
# Min limited by K is : [8]
# Max limited by K is : [19, 17, 18, 15]
# 28 5
# Min limited by K is : [8]
# Max limited by K is : [19, 17, 18, 15, 0]
# 28 5
# Expriment 29
#
# Maximizer finds its target agent:
# Max Action:    Agent18 's opinion 0.429821582429157 changed to 1
# Min Action:    Agent16 's opinion 0.8814892001220932 changed to 0.029210675900751767
# Network reaches equilibrium Polarization: 0.03411560478642941
# Min limited by K is : [6]
# Max limited by K is : [18]
# difference in prediction:0.020130933135071367
# Min limited by K is : [6]
# Max limited by K is : [18, 19]
# 29 5
# Min limited by K is : [6]
# Max limited by K is : [18, 19, 16]
# 29 5
# Min limited by K is : [6]
# Max limited by K is : [18, 19, 16, 17]
# 29 5
# Min limited by K is : [6]
# Max limited by K is : [18, 19, 16, 17, 0]
# 29 5
# Expriment 30
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.0967369947850667 changed to 1
# Min Action:    Agent18 's opinion 0.9505874334602296 changed to 0
# Network reaches equilibrium Polarization: 0.10808503552099426
# Min limited by K is : [7]
# Max limited by K is : [19]
# difference in prediction:0.08114372232934682
# Min limited by K is : [7]
# Max limited by K is : [19, 18]
# 30 5
# Min limited by K is : [7]
# Max limited by K is : [19, 18, 16]
# 30 5
# Min limited by K is : [7]
# Max limited by K is : [19, 18, 16, 17]
# 30 5
# Min limited by K is : [7]
# Max limited by K is : [19, 18, 16, 17, 15]
# 30 5
# Expriment 31
#
# Maximizer finds its target agent:
# Max Action:    Agent18 's opinion 0.6680495461315785 changed to 1
# Min Action:    Agent16 's opinion 0.9620976090071779 changed to 0.33624156983240033
# Network reaches equilibrium Polarization: 0.05587259646506304
# Min limited by K is : [16]
# Max limited by K is : [18]
# difference in prediction:0.0007732844918199172
# Min limited by K is : [16]
# Max limited by K is : [18, 19]
# 31 6
# Min limited by K is : [16]
# Max limited by K is : [18, 19, 17]
# 31 6
# Min limited by K is : [16]
# Max limited by K is : [18, 19, 17, 16]
# 31 6
# Min limited by K is : [16]
# Max limited by K is : [18, 19, 17, 16, 14]
# 31 6
# Expriment 32
#
# Maximizer finds its target agent:
# Max Action:    Agent17 's opinion 0.24523396710375045 changed to 0
# Min Action:    Agent3 's opinion 0.9634413406965331 changed to 0.11380786379120854
# Network reaches equilibrium Polarization: 0.026219763521835034
# Min limited by K is : [3]
# Max limited by K is : [17]
# difference in prediction:0.001430098256085803
# Min limited by K is : [3]
# Max limited by K is : [17, 19]
# 32 7
# Min limited by K is : [3]
# Max limited by K is : [17, 19, 18]
# 32 7
# Min limited by K is : [3]
# Max limited by K is : [17, 19, 18, 1]
# 32 7
# Min limited by K is : [3]
# Max limited by K is : [17, 19, 18, 1, 14]
# 32 7
# Expriment 33
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.7167921421698106 changed to 1
# Min Action:    Agent4 's opinion 0.036970800703584605 changed to 0.9569115917848651
# Network reaches equilibrium Polarization: 0.028004452693315043
# Min limited by K is : [16]
# Max limited by K is : [19]
# difference in prediction:0.0041870570570598925
# Min limited by K is : [16]
# Max limited by K is : [19, 17]
# 33 7
# Min limited by K is : [16]
# Max limited by K is : [19, 17, 18]
# 33 7
# Min limited by K is : [16]
# Max limited by K is : [19, 17, 18, 14]
# 33 7
# Min limited by K is : [16]
# Max limited by K is : [19, 17, 18, 14, 12]
# 33 7
# Expriment 34
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.003846641263337447 changed to 1
# Min Action:    Agent18 's opinion 0.6848063278444266 changed to 0
# Network reaches equilibrium Polarization: 0.07373132061817689
# Min limited by K is : [8]
# Max limited by K is : [19]
# difference in prediction:0.04456570882970114
# Min limited by K is : [8]
# Max limited by K is : [19, 18]
# 34 7
# Min limited by K is : [8]
# Max limited by K is : [19, 18, 17]
# 34 7
# Min limited by K is : [8]
# Max limited by K is : [19, 18, 17, 16]
# 34 7
# Min limited by K is : [8]
# Max limited by K is : [19, 18, 17, 16, 15]
# 34 7
# Expriment 35
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.6877769373962823 changed to 0
# Min Action:    Agent17 's opinion 0.7839221446642691 changed to 0
# Network reaches equilibrium Polarization: 0.07983387264838279
# Min limited by K is : [10]
# Max limited by K is : [19]
# difference in prediction:0.022939135860929008
# Min limited by K is : [10]
# Max limited by K is : [19, 18]
# 35 7
# Min limited by K is : [10]
# Max limited by K is : [19, 18, 17]
# 35 7
# Min limited by K is : [10]
# Max limited by K is : [19, 18, 17, 15]
# 35 7
# Min limited by K is : [10]
# Max limited by K is : [19, 18, 17, 15, 1]
# 35 7
# Expriment 36
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.3482218234490224 changed to 1
# Min Action:    Agent17 's opinion 0.11062921665768322 changed to 0.4940118350120191
# Network reaches equilibrium Polarization: 0.020904873311508865
# Min limited by K is : [4]
# Max limited by K is : [19]
# difference in prediction:0.004806838689181456
# Min limited by K is : [4]
# Max limited by K is : [19, 18]
# 36 7
# Min limited by K is : [4]
# Max limited by K is : [19, 18, 17]
# 36 7
# Min limited by K is : [4]
# Max limited by K is : [19, 18, 17, 15]
# 36 7
# Min limited by K is : [4]
# Max limited by K is : [19, 18, 17, 15, 16]
# 36 7
# Expriment 37
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5911263462879868 changed to 0
# Min Action:    Agent12 's opinion 0.7376180098547037 changed to 0.0531851785381582
# Network reaches equilibrium Polarization: 0.03078895288441091
# Min limited by K is : [13]
# Max limited by K is : [19]
# difference in prediction:0.002763903904948673
# Min limited by K is : [13]
# Max limited by K is : [19, 17]
# 37 7
# Min limited by K is : [13]
# Max limited by K is : [19, 17, 18]
# 37 7
# Min limited by K is : [13]
# Max limited by K is : [19, 17, 18, 15]
# 37 7
# Min limited by K is : [13]
# Max limited by K is : [19, 17, 18, 15, 12]
# 37 7
# Expriment 38
#
# Maximizer finds its target agent:
# Max Action:    Agent18 's opinion 0.5358264271719149 changed to 0
# Min Action:    Agent19 's opinion 0.42025916029777155 changed to 0.7723911881135457
# Network reaches equilibrium Polarization: 0.020796757434453715
# Min limited by K is : [1]
# Max limited by K is : [19]
# difference in prediction:0.0010818801739719344
# Min limited by K is : [1]
# Max limited by K is : [19, 18]
# 38 7
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 17]
# 38 7
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 17, 16]
# 38 7
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 17, 16, 2]
# 38 7
# Expriment 39
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5194470581225104 changed to 1
# Min Action:    Agent7 's opinion 0.0774306965353222 changed to 0.634311007717736
# Network reaches equilibrium Polarization: 0.016184061679763245
# Min limited by K is : [12]
# Max limited by K is : [19]
# difference in prediction:0.00229301944047881
# Min limited by K is : [12]
# Max limited by K is : [19, 18]
# 39 7
# Min limited by K is : [12]
# Max limited by K is : [19, 18, 17]
# 39 7
# Min limited by K is : [12]
# Max limited by K is : [19, 18, 17, 16]
# 39 7
# Min limited by K is : [12]
# Max limited by K is : [19, 18, 17, 16, 7]
# 39 7
# Expriment 40
#
# Maximizer finds its target agent:
# Max Action:    Agent18 's opinion 0.5046424147910559 changed to 1
# Min Action:    Agent17 's opinion 0.8062786980292996 changed to 0
# Network reaches equilibrium Polarization: 0.06202604463765896
# Min limited by K is : [10]
# Max limited by K is : [19]
# difference in prediction:0.05952803930093086
# Min limited by K is : [10]
# Max limited by K is : [19, 17]
# 39 7
# Min limited by K is : [10]
# Max limited by K is : [19, 17, 18]
# 40 7
# Min limited by K is : [10]
# Max limited by K is : [19, 17, 18, 16]
# 40 7
# Min limited by K is : [10]
# Max limited by K is : [19, 17, 18, 16, 14]
# 40 7
# Expriment 41
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.7535200834976412 changed to 0
# Min Action:    Agent14 's opinion 0.9827798546308207 changed to 0
# Network reaches equilibrium Polarization: 0.26717447347299583
# Min limited by K is : [14]
# Max limited by K is : [19]
# difference in prediction:0.02804963970126978
# Min limited by K is : [14]
# Max limited by K is : [19, 18]
# 40 8
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17]
# 41 8
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16]
# 41 8
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16, 14]
# 41 8
# Expriment 42
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.010662628333836022 changed to 0
# Min Action:    Agent16 's opinion 0.9059696100217286 changed to 0
# Network reaches equilibrium Polarization: 0.03579241317545336
# Min limited by K is : [13]
# Max limited by K is : [19]
# difference in prediction:0.00626978565589438
# Min limited by K is : [13]
# Max limited by K is : [19, 18]
# 41 8
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 17]
# 42 8
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 17, 15]
# 42 8
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 17, 15, 14]
# 42 8
# Expriment 43
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.917369567851848 changed to 0
# Min Action:    Agent2 's opinion 0.9095238555074185 changed to 0
# Network reaches equilibrium Polarization: 0.04215797401036542
# Min limited by K is : [14]
# Max limited by K is : [17]
# difference in prediction:0.010189463084595125
# Min limited by K is : [14]
# Max limited by K is : [17, 19]
# 42 8
# Min limited by K is : [14]
# Max limited by K is : [17, 19, 18]
# 43 8
# Min limited by K is : [14]
# Max limited by K is : [17, 19, 18, 16]
# 43 8
# Min limited by K is : [14]
# Max limited by K is : [17, 19, 18, 16, 15]
# 43 8
# Expriment 44
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.8149397147679256 changed to 0
# Min Action:    Agent5 's opinion 0.9535737529653054 changed to 0
# Network reaches equilibrium Polarization: 0.32801536913809276
# Min limited by K is : [17]
# Max limited by K is : [19]
# difference in prediction:0.03602179069377287
# Min limited by K is : [17]
# Max limited by K is : [19, 16]
# 43 8
# Min limited by K is : [17]
# Max limited by K is : [19, 16, 18]
# 44 8
# Min limited by K is : [17]
# Max limited by K is : [19, 16, 18, 17]
# 44 8
# Min limited by K is : [17]
# Max limited by K is : [19, 16, 18, 17, 14]
# 44 8
# Expriment 45
#
# Maximizer finds its target agent:
# Max Action:    Agent18 's opinion 0.3419956643238473 changed to 0
# Min Action:    Agent5 's opinion 0.9835744492750955 changed to 0
# Network reaches equilibrium Polarization: 0.04255022141244814
# Min limited by K is : [5]
# Max limited by K is : [18]
# difference in prediction:0.005959073571253977
# Min limited by K is : [5]
# Max limited by K is : [18, 19]
# 44 9
# Min limited by K is : [5]
# Max limited by K is : [18, 19, 16]
# 45 9
# Min limited by K is : [5]
# Max limited by K is : [18, 19, 16, 17]
# 45 9
# Min limited by K is : [5]
# Max limited by K is : [18, 19, 16, 17, 14]
# 45 9
# Expriment 46
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.9972650962821112 changed to 0
# Min Action:    Agent1 's opinion 0.87130689299162 changed to 0
# Network reaches equilibrium Polarization: 0.07704407026279013
# Min limited by K is : [19]
# Max limited by K is : [19]
# difference in prediction:0.06448642581667147
# Min limited by K is : [19]
# Max limited by K is : [19, 17]
# 45 9
# Min limited by K is : [19]
# Max limited by K is : [19, 17, 15]
# 46 9
# Min limited by K is : [19]
# Max limited by K is : [19, 17, 15, 18]
# 46 9
# Min limited by K is : [19]
# Max limited by K is : [19, 17, 15, 18, 3]
# 46 9
# Expriment 47
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.2543210831515961 changed to 1
# Min Action:    Agent9 's opinion 0.02192038179192679 changed to 1
# Network reaches equilibrium Polarization: 0.041809831498756465
# Min limited by K is : [13]
# Max limited by K is : [19]
# difference in prediction:0.010532879106820998
# Min limited by K is : [13]
# Max limited by K is : [19, 17]
# 46 9
# Min limited by K is : [13]
# Max limited by K is : [19, 17, 16]
# 47 9
# Min limited by K is : [13]
# Max limited by K is : [19, 17, 16, 18]
# 47 9
# Min limited by K is : [13]
# Max limited by K is : [19, 17, 16, 18, 11]
# 47 9
# Expriment 48
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5270560397324503 changed to 0
# Min Action:    Agent18 's opinion 0.18879276100503628 changed to 0.6817948183518517
# Network reaches equilibrium Polarization: 0.038954662664904285
# Min limited by K is : [4]
# Max limited by K is : [19]
# difference in prediction:0.0025052645605504603
# Min limited by K is : [4]
# Max limited by K is : [19, 18]
# 47 9
# Min limited by K is : [4]
# Max limited by K is : [19, 18, 17]
# 48 9
# Min limited by K is : [4]
# Max limited by K is : [19, 18, 17, 16]
# 48 9
# Min limited by K is : [4]
# Max limited by K is : [19, 18, 17, 16, 8]
# 48 9
# Expriment 49
#
# Maximizer finds its target agent:
# Max Action:    Agent17 's opinion 0.7471143001694355 changed to 0
# Min Action:    Agent15 's opinion 0.975447482820101 changed to 0
# Network reaches equilibrium Polarization: 0.09622294006522453
# Min limited by K is : [15]
# Max limited by K is : [17]
# difference in prediction:0.00732802941912121
# Min limited by K is : [15]
# Max limited by K is : [17, 18]
# 48 10
# Min limited by K is : [15]
# Max limited by K is : [17, 18, 19]
# 49 10
# Min limited by K is : [15]
# Max limited by K is : [17, 18, 19, 16]
# 49 10
# Min limited by K is : [15]
# Max limited by K is : [17, 18, 19, 16, 15]
# 49 10
# Expriment 50
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.77270069647359 changed to 0
# Min Action:    Agent17 's opinion 0.951119235626062 changed to 0.2605028661729602
# Network reaches equilibrium Polarization: 0.04039223359060426
# Min limited by K is : [17]
# Max limited by K is : [19]
# difference in prediction:0.0024802386121145145
# Min limited by K is : [17]
# Max limited by K is : [19, 17]
# 49 11
# Min limited by K is : [17]
# Max limited by K is : [19, 17, 18]
# 50 11
# Min limited by K is : [17]
# Max limited by K is : [19, 17, 18, 1]
# 50 11
# Min limited by K is : [17]
# Max limited by K is : [19, 17, 18, 1, 15]
# 50 11
# Expriment 51
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.9445934237834789 changed to 0
# Min Action:    Agent9 's opinion 0.8576324806081564 changed to 0
# Network reaches equilibrium Polarization: 0.2533452189992162
# Min limited by K is : [19]
# Max limited by K is : [19]
# difference in prediction:0.22093693494728014
# Min limited by K is : [19]
# Max limited by K is : [19, 18]
# 50 11
# Min limited by K is : [19]
# Max limited by K is : [19, 18, 17]
# 51 11
# Min limited by K is : [19]
# Max limited by K is : [19, 18, 17, 0]
# 51 11
# Min limited by K is : [19]
# Max limited by K is : [19, 18, 17, 0, 4]
# 51 11
# Expriment 52
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.2660307924414589 changed to 1
# Min Action:    Agent17 's opinion 0.06213424630324549 changed to 0.614793637386986
# Network reaches equilibrium Polarization: 0.03415954605534724
# Min limited by K is : [7]
# Max limited by K is : [19]
# difference in prediction:0.005702805690384352
# Min limited by K is : [7]
# Max limited by K is : [19, 15]
# 51 11
# Min limited by K is : [7]
# Max limited by K is : [19, 15, 18]
# 52 11
# Min limited by K is : [7]
# Max limited by K is : [19, 15, 18, 17]
# 52 11
# Min limited by K is : [7]
# Max limited by K is : [19, 15, 18, 17, 16]
# 52 11
# Expriment 53
#
# Maximizer finds its target agent:
# Max Action:    Agent16 's opinion 0.6109593078665511 changed to 1
# Min Action:    Agent3 's opinion 0.22570663209764763 changed to 1
# Network reaches equilibrium Polarization: 0.022556394416267986
# Min limited by K is : [4]
# Max limited by K is : [19]
# difference in prediction:0.006511682549290548
# Min limited by K is : [4]
# Max limited by K is : [19, 16]
# 52 11
# Min limited by K is : [4]
# Max limited by K is : [19, 16, 17]
# 53 11
# Min limited by K is : [4]
# Max limited by K is : [19, 16, 17, 14]
# 53 11
# Min limited by K is : [4]
# Max limited by K is : [19, 16, 17, 14, 13]
# 53 11
# Expriment 54
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.2156702684148496 changed to 1
# Min Action:    Agent16 's opinion 0.014873078104353454 changed to 1
# Network reaches equilibrium Polarization: 0.05350876544398426
# Min limited by K is : [5]
# Max limited by K is : [19]
# difference in prediction:0.012031291705581475
# Min limited by K is : [5]
# Max limited by K is : [19, 18]
# 53 11
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 14]
# 54 11
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 14, 6]
# 54 11
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 14, 6, 17]
# 54 11
# Expriment 55
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.6602693028186398 changed to 1
# Min Action:    Agent2 's opinion 0.009813641801024842 changed to 0.7618199964136338
# Network reaches equilibrium Polarization: 0.034250680521591303
# Min limited by K is : [11]
# Max limited by K is : [19]
# difference in prediction:0.00487772426118873
# Min limited by K is : [11]
# Max limited by K is : [19, 18]
# 54 11
# Min limited by K is : [11]
# Max limited by K is : [19, 18, 17]
# 55 11
# Min limited by K is : [11]
# Max limited by K is : [19, 18, 17, 16]
# 55 11
# Min limited by K is : [11]
# Max limited by K is : [19, 18, 17, 16, 15]
# 55 11
# Expriment 56
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.1992692603601608 changed to 1
# Min Action:    Agent18 's opinion 0.9085367192526169 changed to 0.281594466191087
# Network reaches equilibrium Polarization: 0.05631789020457796
# Min limited by K is : [14]
# Max limited by K is : [19]
# difference in prediction:0.02590530707407436
# Min limited by K is : [14]
# Max limited by K is : [19, 18]
# 55 11
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17]
# 56 11
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16]
# 56 11
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16, 2]
# 56 11
# Expriment 57
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.17924312356349736 changed to 1
# Min Action:    Agent12 's opinion 0.03456018779256542 changed to 1
# Network reaches equilibrium Polarization: 0.04565684051627913
# Min limited by K is : [4]
# Max limited by K is : [19]
# difference in prediction:0.01449127141201658
# Min limited by K is : [4]
# Max limited by K is : [19, 18]
# 56 11
# Min limited by K is : [4]
# Max limited by K is : [19, 18, 17]
# 57 11
# Min limited by K is : [4]
# Max limited by K is : [19, 18, 17, 1]
# 57 11
# Min limited by K is : [4]
# Max limited by K is : [19, 18, 17, 1, 15]
# 57 11
# Expriment 58
#
# Maximizer finds its target agent:
# Max Action:    Agent18 's opinion 0.39006191865934237 changed to 0
# Min Action:    Agent19 's opinion 0.04580125721703199 changed to 0.7344701434232014
# Network reaches equilibrium Polarization: 0.034669445794784266
# Min limited by K is : [8]
# Max limited by K is : [19]
# difference in prediction:0.02988421988708611
# Min limited by K is : [8]
# Max limited by K is : [19, 17]
# 56 11
# Min limited by K is : [8]
# Max limited by K is : [19, 17, 18]
# 58 11
# Min limited by K is : [8]
# Max limited by K is : [19, 17, 18, 16]
# 58 11
# Min limited by K is : [8]
# Max limited by K is : [19, 17, 18, 16, 15]
# 58 11
# Expriment 59
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.13403611025437612 changed to 0
# Min Action:    Agent7 's opinion 0.8478899971797416 changed to 0
# Network reaches equilibrium Polarization: 0.03778375269674208
# Min limited by K is : [15]
# Max limited by K is : [19]
# difference in prediction:0.00802878382391918
# Min limited by K is : [15]
# Max limited by K is : [19, 13]
# 57 11
# Min limited by K is : [15]
# Max limited by K is : [19, 13, 0]
# 59 11
# Min limited by K is : [15]
# Max limited by K is : [19, 13, 0, 18]
# 59 11
# Min limited by K is : [15]
# Max limited by K is : [19, 13, 0, 18, 17]
# 59 11
# Expriment 60
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.6572791777039866 changed to 1
# Min Action:    Agent18 's opinion 0.8287228335285062 changed to 0.013137376037360315
# Network reaches equilibrium Polarization: 0.06694336051358829
# Min limited by K is : [5]
# Max limited by K is : [19]
# difference in prediction:0.07007683906759993
# Min limited by K is : [5]
# Max limited by K is : [19, 18]
# 58 11
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 17]
# 60 11
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 17, 16]
# 60 11
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 17, 16, 15]
# 60 11
# Expriment 61
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5386506641650292 changed to 0
# Min Action:    Agent8 's opinion 0.9238190173855467 changed to 0
# Network reaches equilibrium Polarization: 0.10570445105073466
# Min limited by K is : [9]
# Max limited by K is : [19]
# difference in prediction:0.01014515736071292
# Min limited by K is : [9]
# Max limited by K is : [19, 16]
# 59 11
# Min limited by K is : [9]
# Max limited by K is : [19, 16, 18]
# 61 11
# Min limited by K is : [9]
# Max limited by K is : [19, 16, 18, 17]
# 61 11
# Min limited by K is : [9]
# Max limited by K is : [19, 16, 18, 17, 0]
# 61 11
# Expriment 62
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.49233043616816063 changed to 0
# Min Action:    Agent14 's opinion 0.8559250416908346 changed to 0.23182405152398153
# Network reaches equilibrium Polarization: 0.029289910869199468
# Min limited by K is : [13]
# Max limited by K is : [19]
# difference in prediction:0.0013291437373038409
# Min limited by K is : [13]
# Max limited by K is : [19, 18]
# 60 11
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 14]
# 62 11
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 14, 3]
# 62 11
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 14, 3, 13]
# 62 11
# Expriment 63
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5355770867370079 changed to 0
# Min Action:    Agent2 's opinion 0.9929976067289376 changed to 0.004783910647040696
# Network reaches equilibrium Polarization: 0.03708020400035958
# Min limited by K is : [2]
# Max limited by K is : [19]
# difference in prediction:0.0025387563047828063
# Min limited by K is : [2]
# Max limited by K is : [19, 18]
# 61 12
# Min limited by K is : [2]
# Max limited by K is : [19, 18, 14]
# 63 12
# Min limited by K is : [2]
# Max limited by K is : [19, 18, 14, 16]
# 63 12
# Min limited by K is : [2]
# Max limited by K is : [19, 18, 14, 16, 0]
# 63 12
# Expriment 64
#
# Maximizer finds its target agent:
# Max Action:    Agent17 's opinion 0.5666292040503715 changed to 0
# Min Action:    Agent18 's opinion 0.17584187744811297 changed to 0.5270262896361075
# Network reaches equilibrium Polarization: 0.06975592364691194
# Min limited by K is : [0]
# Max limited by K is : [17]
# difference in prediction:0.010259831098894917
# Min limited by K is : [0]
# Max limited by K is : [17, 19]
# 62 12
# Min limited by K is : [0]
# Max limited by K is : [17, 19, 18]
# 64 12
# Min limited by K is : [0]
# Max limited by K is : [17, 19, 18, 16]
# 64 12
# Min limited by K is : [0]
# Max limited by K is : [17, 19, 18, 16, 15]
# 64 12
# Expriment 65
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.46201529420680587 changed to 0
# Min Action:    Agent11 's opinion 0.9975822235096642 changed to 0
# Network reaches equilibrium Polarization: 0.09371097056581146
# Min limited by K is : [11]
# Max limited by K is : [19]
# difference in prediction:0.012789368454791936
# Min limited by K is : [11]
# Max limited by K is : [19, 18]
# 63 13
# Min limited by K is : [11]
# Max limited by K is : [19, 18, 17]
# 65 13
# Min limited by K is : [11]
# Max limited by K is : [19, 18, 17, 0]
# 65 13
# Min limited by K is : [11]
# Max limited by K is : [19, 18, 17, 0, 13]
# 65 13
# Expriment 66
#
# Maximizer finds its target agent:
# Max Action:    Agent18 's opinion 0.18516344080020053 changed to 1
# Min Action:    Agent19 's opinion 0.09648897922646427 changed to 0.6686851454839171
# Network reaches equilibrium Polarization: 0.052031580420223954
# Min limited by K is : [16]
# Max limited by K is : [18]
# difference in prediction:0.0043448894139793345
# Min limited by K is : [16]
# Max limited by K is : [18, 19]
# 64 13
# Min limited by K is : [16]
# Max limited by K is : [18, 19, 17]
# 66 13
# Min limited by K is : [16]
# Max limited by K is : [18, 19, 17, 16]
# 66 13
# Min limited by K is : [16]
# Max limited by K is : [18, 19, 17, 16, 13]
# 66 13
# Expriment 67
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.6158556958467682 changed to 0
# Min Action:    Agent17 's opinion 0.3104577292279218 changed to 0.9347085562899731
# Network reaches equilibrium Polarization: 0.039220153795589935
# Min limited by K is : [18]
# Max limited by K is : [19]
# difference in prediction:0.024827509065459455
# Min limited by K is : [18]
# Max limited by K is : [19, 17]
# 65 13
# Min limited by K is : [18]
# Max limited by K is : [19, 17, 18]
# 67 13
# Min limited by K is : [18]
# Max limited by K is : [19, 17, 18, 15]
# 67 13
# Min limited by K is : [18]
# Max limited by K is : [19, 17, 18, 15, 16]
# 67 13
# Expriment 68
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.9919276761602054 changed to 1
# Min Action:    Agent1 's opinion 0.24248019183747882 changed to 1
# Network reaches equilibrium Polarization: 0.04068783271504489
# Min limited by K is : [7]
# Max limited by K is : [19]
# difference in prediction:0.018135099982228765
# Min limited by K is : [7]
# Max limited by K is : [19, 18]
# 66 13
# Min limited by K is : [7]
# Max limited by K is : [19, 18, 17]
# 68 13
# Min limited by K is : [7]
# Max limited by K is : [19, 18, 17, 16]
# 68 13
# Min limited by K is : [7]
# Max limited by K is : [19, 18, 17, 16, 14]
# 68 13
# Expriment 69
#
# Maximizer finds its target agent:
# Max Action:    Agent4 's opinion 0.9972845873832078 changed to 0
# Min Action:    Agent17 's opinion 0.9362956521074677 changed to 0.1683233962141832
# Network reaches equilibrium Polarization: 0.03520992030682628
# Min limited by K is : [4]
# Max limited by K is : [14]
# difference in prediction:0.00451036216559892
# Min limited by K is : [4]
# Max limited by K is : [14, 17]
# 66 13
# Min limited by K is : [4]
# Max limited by K is : [14, 17, 19]
# 68 13
# Min limited by K is : [4]
# Max limited by K is : [14, 17, 19, 15]
# 68 13
# Min limited by K is : [4]
# Max limited by K is : [14, 17, 19, 15, 18]
# 68 13
# Expriment 70
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5322059489022528 changed to 1
# Min Action:    Agent18 's opinion 0.032007636996637 changed to 0.5593896576779193
# Network reaches equilibrium Polarization: 0.04333011956186428
# Min limited by K is : [12]
# Max limited by K is : [19]
# difference in prediction:0.01013970583724872
# Min limited by K is : [12]
# Max limited by K is : [19, 17]
# 67 13
# Min limited by K is : [12]
# Max limited by K is : [19, 17, 18]
# 69 13
# Min limited by K is : [12]
# Max limited by K is : [19, 17, 18, 13]
# 69 13
# Min limited by K is : [12]
# Max limited by K is : [19, 17, 18, 13, 16]
# 69 13
# Expriment 71
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.11346964571527551 changed to 0
# Min Action:    Agent0 's opinion 0.9545980150797558 changed to 0.16990887403655394
# Network reaches equilibrium Polarization: 0.018202414583916988
# Min limited by K is : [0]
# Max limited by K is : [19]
# difference in prediction:0.0010382311866525065
# Min limited by K is : [0]
# Max limited by K is : [19, 18]
# 68 14
# Min limited by K is : [0]
# Max limited by K is : [19, 18, 17]
# 70 14
# Min limited by K is : [0]
# Max limited by K is : [19, 18, 17, 16]
# 70 14
# Min limited by K is : [0]
# Max limited by K is : [19, 18, 17, 16, 1]
# 70 14
# Expriment 72
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.1478860855529569 changed to 0
# Min Action:    Agent18 's opinion 0.3213249698179961 changed to 0.7946495552047289
# Network reaches equilibrium Polarization: 0.039170514582476654
# Min limited by K is : [6]
# Max limited by K is : [18]
# difference in prediction:0.01156502569256928
# Min limited by K is : [6]
# Max limited by K is : [18, 19]
# 69 14
# Min limited by K is : [6]
# Max limited by K is : [18, 19, 17]
# 71 14
# Min limited by K is : [6]
# Max limited by K is : [18, 19, 17, 16]
# 71 14
# Min limited by K is : [6]
# Max limited by K is : [18, 19, 17, 16, 15]
# 71 14
# Expriment 73
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.09126768941521757 changed to 0
# Min Action:    Agent15 's opinion 0.9126375288610437 changed to 0.3902877058997983
# Network reaches equilibrium Polarization: 0.030073337799884747
# Min limited by K is : [10]
# Max limited by K is : [19]
# difference in prediction:0.0017889112652283087
# Min limited by K is : [10]
# Max limited by K is : [19, 17]
# 70 14
# ...
# 75 15
# Expriment 77
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.9636529547970739 changed to 1
# Min Action:    Agent13 's opinion 0.051227345565781124 changed to 0.9632766133453942
# Network reaches equilibrium Polarization: 0.044040958727650535
# Min limited by K is : [8]
# Max limited by K is : [19]
# difference in prediction:0.009987068738523917
# Min limited by K is : [8]
# Max limited by K is : [19, 15]
# 74 15
# Min limited by K is : [8]
# Max limited by K is : [19, 15, 18]
# 76 15
# Min limited by K is : [8]
# Max limited by K is : [19, 15, 18, 17]
# 76 15
# Min limited by K is : [8]
# Max limited by K is : [19, 15, 18, 17, 16]
# 76 15
# Expriment 78
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.79573629748096 changed to 0
# Min Action:    Agent18 's opinion 0.053182234974807785 changed to 0.8241478167220818
# Network reaches equilibrium Polarization: 0.03085696107372744
# Min limited by K is : [14]
# Max limited by K is : [19]
# difference in prediction:0.01948574405502657
# Min limited by K is : [14]
# Max limited by K is : [19, 18]
# 75 15
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17]
# 77 15
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16]
# 77 15
# Min limited by K is : [14]
# Max limited by K is : [19, 18, 17, 16, 3]
# 77 15
# Expriment 79
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.3176942975273396 changed to 0
# Min Action:    Agent0 's opinion 0.8820720904211988 changed to 0
# Network reaches equilibrium Polarization: 0.08115706959997607
# Min limited by K is : [13]
# Max limited by K is : [19]
# difference in prediction:0.008361355232509443
# Min limited by K is : [13]
# Max limited by K is : [19, 18]
# 76 15
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 16]
# 78 15
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 16, 17]
# 78 15
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 16, 17, 14]
# 78 15
# Expriment 80
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.4198246597467221 changed to 0
# Min Action:    Agent18 's opinion 0.9357154328499345 changed to 0
# Network reaches equilibrium Polarization: 0.2706242258755785
# Min limited by K is : [14]
# Max limited by K is : [19]
# difference in prediction:0.0242502764117854
# Min limited by K is : [14]
# Max limited by K is : [19, 14]
# 77 15
# Min limited by K is : [14]
# Max limited by K is : [19, 14, 18]
# 79 15
# Min limited by K is : [14]
# Max limited by K is : [19, 14, 18, 17]
# 79 15
# Min limited by K is : [14]
# Max limited by K is : [19, 14, 18, 17, 16]
# 79 15
# Expriment 81
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.6662841690396063 changed to 1
# Min Action:    Agent4 's opinion 0.039683546950872506 changed to 1
# Network reaches equilibrium Polarization: 0.030634236821443204
# Min limited by K is : [2]
# Max limited by K is : [19]
# difference in prediction:0.0102566044448268
# Min limited by K is : [2]
# Max limited by K is : [19, 18]
# 78 15
# Min limited by K is : [2]
# Max limited by K is : [19, 18, 17]
# 80 15
# Min limited by K is : [2]
# Max limited by K is : [19, 18, 17, 16]
# 80 15
# Min limited by K is : [2]
# Max limited by K is : [19, 18, 17, 16, 14]
# 80 15
# Expriment 82
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.6720850314666562 changed to 1
# Min Action:    Agent18 's opinion 0.9468733323853509 changed to 0.2541622388496238
# Network reaches equilibrium Polarization: 0.038129537677856505
# Min limited by K is : [6]
# Max limited by K is : [19]
# difference in prediction:0.026061439922396283
# Min limited by K is : [6]
# Max limited by K is : [19, 18]
# 79 15
# Min limited by K is : [6]
# Max limited by K is : [19, 18, 16]
# 81 15
# Min limited by K is : [6]
# Max limited by K is : [19, 18, 16, 14]
# 81 15
# Min limited by K is : [6]
# Max limited by K is : [19, 18, 16, 14, 11]
# 81 15
# Expriment 83
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.8947206620325392 changed to 0
# Min Action:    Agent1 's opinion 0.8418220643067026 changed to 0.0945906775313151
# Network reaches equilibrium Polarization: 0.02326352440189018
# Min limited by K is : [19]
# Max limited by K is : [19]
# difference in prediction:0.011832465083217263
# Min limited by K is : [19]
# Max limited by K is : [19, 17]
# 80 15
# Min limited by K is : [19]
# Max limited by K is : [19, 17, 16]
# 82 15
# Min limited by K is : [19]
# Max limited by K is : [19, 17, 16, 11]
# 82 15
# Min limited by K is : [19]
# Max limited by K is : [19, 17, 16, 11, 18]
# 82 15
# Expriment 84
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.8069290443063446 changed to 1
# Min Action:    Agent18 's opinion 0.9953042234241447 changed to 0.35851995761774047
# Network reaches equilibrium Polarization: 0.042807134527047375
# Min limited by K is : [18]
# Max limited by K is : [19]
# difference in prediction:0.00034756214185731327
# Min limited by K is : [18]
# Max limited by K is : [19, 18]
# 81 16
# Min limited by K is : [18]
# Max limited by K is : [19, 18, 17]
# 83 16
# Min limited by K is : [18]
# Max limited by K is : [19, 18, 17, 2]
# 83 16
# Min limited by K is : [18]
# Max limited by K is : [19, 18, 17, 2, 16]
# 83 16
# Expriment 85
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.35694974734684615 changed to 1
# Min Action:    Agent16 's opinion 0.07084203932539923 changed to 0.8039458288210207
# Network reaches equilibrium Polarization: 0.036631511130617425
# Min limited by K is : [1]
# Max limited by K is : [19]
# difference in prediction:0.005423595367973176
# Min limited by K is : [1]
# Max limited by K is : [19, 18]
# 82 16
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 17]
# 84 16
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 17, 1]
# 84 16
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 17, 1, 0]
# 84 16
# Expriment 86
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.6089575062336811 changed to 1
# Min Action:    Agent8 's opinion 0.05183121191293538 changed to 1
# Network reaches equilibrium Polarization: 0.06635272924437316
# Min limited by K is : [17]
# Max limited by K is : [19]
# difference in prediction:0.016468763077746543
# Min limited by K is : [17]
# Max limited by K is : [19, 17]
# 83 16
# Min limited by K is : [17]
# Max limited by K is : [19, 17, 18]
# 85 16
# Min limited by K is : [17]
# Max limited by K is : [19, 17, 18, 16]
# 85 16
# Min limited by K is : [17]
# Max limited by K is : [19, 17, 18, 16, 15]
# 85 16
# Expriment 87
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.7915834059330684 changed to 1
# Min Action:    Agent12 's opinion 0.15371723083517908 changed to 1
# Network reaches equilibrium Polarization: 0.06770523568611417
# Min limited by K is : [2]
# Max limited by K is : [19]
# difference in prediction:0.019311133832701458
# Min limited by K is : [2]
# Max limited by K is : [19, 17]
# 84 16
# Min limited by K is : [2]
# Max limited by K is : [19, 17, 14]
# 86 16
# Min limited by K is : [2]
# Max limited by K is : [19, 17, 14, 16]
# 86 16
# Min limited by K is : [2]
# Max limited by K is : [19, 17, 14, 16, 13]
# 86 16
# Expriment 88
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.17034416142656528 changed to 0
# Min Action:    Agent16 's opinion 0.9539381334843614 changed to 0.44349965217735926
# Network reaches equilibrium Polarization: 0.040438695010421445
# Min limited by K is : [12]
# Max limited by K is : [19]
# difference in prediction:0.005005140961650549
# Min limited by K is : [12]
# Max limited by K is : [19, 17]
# 85 16
# Min limited by K is : [12]
# Max limited by K is : [19, 17, 18]
# 87 16
# Min limited by K is : [12]
# Max limited by K is : [19, 17, 18, 16]
# 87 16
# Min limited by K is : [12]
# Max limited by K is : [19, 17, 18, 16, 15]
# 87 16
# Expriment 89
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.5629179163352839 changed to 0
# Min Action:    Agent18 's opinion 0.9573182266851645 changed to 0.4177669888216111
# Network reaches equilibrium Polarization: 0.031587783808356334
# Min limited by K is : [11]
# Max limited by K is : [19]
# difference in prediction:0.007311591183416261
# Min limited by K is : [11]
# Max limited by K is : [19, 18]
# 86 16
# Min limited by K is : [11]
# Max limited by K is : [19, 18, 17]
# 88 16
# Min limited by K is : [11]
# Max limited by K is : [19, 18, 17, 16]
# 88 16
# Min limited by K is : [11]
# Max limited by K is : [19, 18, 17, 16, 15]
# 88 16
# Expriment 90
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.2533895424045358 changed to 0
# Min Action:    Agent1 's opinion 0.9373219668857588 changed to 0
# Network reaches equilibrium Polarization: 0.03818430423735521
# Min limited by K is : [9]
# Max limited by K is : [19]
# difference in prediction:0.002447786730659665
# Min limited by K is : [9]
# Max limited by K is : [19, 18]
# 87 16
# Min limited by K is : [9]
# Max limited by K is : [19, 18, 17]
# 89 16
# Min limited by K is : [9]
# Max limited by K is : [19, 18, 17, 2]
# 89 16
# Min limited by K is : [9]
# Max limited by K is : [19, 18, 17, 2, 16]
# 89 16
# Expriment 91
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.588441052587747 changed to 0
# Min Action:    Agent18 's opinion 0.11501328243119524 changed to 0.5891686766489956
# Network reaches equilibrium Polarization: 0.0150261238772067
# Min limited by K is : [9]
# Max limited by K is : [19]
# difference in prediction:0.0026518181732857003
# Min limited by K is : [9]
# Max limited by K is : [19, 18]
# 88 16
# Min limited by K is : [9]
# Max limited by K is : [19, 18, 17]
# 90 16
# Min limited by K is : [9]
# Max limited by K is : [19, 18, 17, 13]
# 90 16
# Min limited by K is : [9]
# Max limited by K is : [19, 18, 17, 13, 1]
# 90 16
# Expriment 92
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.3655041322818864 changed to 0
# Min Action:    Agent8 's opinion 0.9506274772792239 changed to 0.18317526485736801
# Network reaches equilibrium Polarization: 0.028774988293675828
# Min limited by K is : [13]
# Max limited by K is : [19]
# difference in prediction:0.00252783904160727
# Min limited by K is : [13]
# Max limited by K is : [19, 18]
# 89 16
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 17]
# 91 16
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 17, 15]
# 91 16
# Min limited by K is : [13]
# Max limited by K is : [19, 18, 17, 15, 11]
# 91 16
# Expriment 93
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.9902943471894325 changed to 1
# Min Action:    Agent15 's opinion 0.2598137134255941 changed to 1
# Network reaches equilibrium Polarization: 0.04146893890426711
# Min limited by K is : [19]
# Max limited by K is : [19]
# difference in prediction:0.03314048589184221
# Min limited by K is : [19]
# Max limited by K is : [19, 16]
# 90 16
# Min limited by K is : [19]
# Max limited by K is : [19, 16, 18]
# 92 16
# Min limited by K is : [19]
# Max limited by K is : [19, 16, 18, 17]
# 92 16
# Min limited by K is : [19]
# Max limited by K is : [19, 16, 18, 17, 14]
# 92 16
# Expriment 94
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.8339325856320724 changed to 0
# Min Action:    Agent15 's opinion 0.9128293660045503 changed to 0
# Network reaches equilibrium Polarization: 0.06074584865617362
# Min limited by K is : [15]
# Max limited by K is : [19]
# difference in prediction:0.006029955414052601
# Min limited by K is : [15]
# Max limited by K is : [19, 17]
# 91 17
# Min limited by K is : [15]
# Max limited by K is : [19, 17, 15]
# 93 17
# Min limited by K is : [15]
# Max limited by K is : [19, 17, 15, 0]
# 93 17
# Min limited by K is : [15]
# Max limited by K is : [19, 17, 15, 0, 6]
# 93 17
# Expriment 95
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.6943222255155388 changed to 1
# Min Action:    Agent18 's opinion 0.8123994852698826 changed to 0.17756359568428762
# Network reaches equilibrium Polarization: 0.04119040932693241
# Min limited by K is : [15]
# Max limited by K is : [19]
# difference in prediction:0.01176783967290853
# Min limited by K is : [15]
# Max limited by K is : [19, 16]
# 92 17
# Min limited by K is : [15]
# Max limited by K is : [19, 16, 17]
# 94 17
# Min limited by K is : [15]
# Max limited by K is : [19, 16, 17, 18]
# 94 17
# Min limited by K is : [15]
# Max limited by K is : [19, 16, 17, 18, 15]
# 94 17
# Expriment 96
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.8032296666345308 changed to 1
# Min Action:    Agent10 's opinion 0.002183502418238281 changed to 1
# Network reaches equilibrium Polarization: 0.24065482891736228
# Min limited by K is : [8]
# Max limited by K is : [19]
# difference in prediction:0.07589268821024248
# Min limited by K is : [8]
# Max limited by K is : [19, 17]
# 93 17
# Min limited by K is : [8]
# Max limited by K is : [19, 17, 18]
# 95 17
# Min limited by K is : [8]
# Max limited by K is : [19, 17, 18, 14]
# 95 17
# Min limited by K is : [8]
# Max limited by K is : [19, 17, 18, 14, 16]
# 95 17
# Expriment 97
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.323502487691963 changed to 1
# Min Action:    Agent17 's opinion 0.9351447622320959 changed to 0.01821769574842617
# Network reaches equilibrium Polarization: 0.04554039130580058
# Min limited by K is : [5]
# Max limited by K is : [19]
# difference in prediction:0.022075292711737013
# Min limited by K is : [5]
# Max limited by K is : [19, 16]
# 94 17
# Min limited by K is : [5]
# Max limited by K is : [19, 16, 17]
# 96 17
# Min limited by K is : [5]
# Max limited by K is : [19, 16, 17, 18]
# 96 17
# Min limited by K is : [5]
# Max limited by K is : [19, 16, 17, 18, 15]
# 96 17
# Expriment 98
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.49312503651079853 changed to 0
# Min Action:    Agent4 's opinion 0.9611639643262846 changed to 0
# Network reaches equilibrium Polarization: 0.049534921920782536
# Min limited by K is : [1]
# Max limited by K is : [19]
# difference in prediction:0.006276984254617805
# Min limited by K is : [1]
# Max limited by K is : [19, 18]
# 95 17
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 16]
# 97 17
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 16, 17]
# 97 17
# Min limited by K is : [1]
# Max limited by K is : [19, 18, 16, 17, 15]
# 97 17
# Expriment 99
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.19610927748987406 changed to 1
# Min Action:    Agent4 's opinion 0.0108886337995584 changed to 1
# Network reaches equilibrium Polarization: 0.07579688271047054
# Min limited by K is : [5]
# Max limited by K is : [19]
# difference in prediction:0.01717391039512256
# Min limited by K is : [5]
# Max limited by K is : [19, 18]
# 96 17
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 17]
# 98 17
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 17, 15]
# 98 17
# Min limited by K is : [5]
# Max limited by K is : [19, 18, 17, 15, 16]
# 98 17
# Expriment 100
#
# Maximizer finds its target agent:
# Max Action:    Agent19 's opinion 0.49124514064100466 changed to 1
# Min Action:    Agent14 's opinion 0.03247327676161682 changed to 0.7230177468007972
# Network reaches equilibrium Polarization: 0.038005552939744086
# Min limited by K is : [3]
# Max limited by K is : [19]
# difference in prediction:0.012832751745145976
# Min limited by K is : [3]
# Max limited by K is : [19, 18]
# 97 17
# Min limited by K is : [3]
# Max limited by K is : [19, 18, 16]
# 99 17
# Min limited by K is : [3]
# Max limited by K is : [19, 18, 16, 14]
# 99 17
# Min limited by K is : [3]
# Max limited by K is : [19, 18, 16, 14, 12]
# 99 17
# the average polarization difference in predid and actual:-0.010814988404110628
# error % is:28.456337475887416%

# %%
def cal_rate(max_suc_count,min_suc_count):     
    max_suc_rate = max_suc_count/100
    min_suc_rate = min_suc_count/100
    print("Max prediction success rate:"+ str(max_suc_rate))
    print("Min prediction success rate:"+ str(min_suc_rate))
    return(max_suc_rate,min_suc_rate)
print("Prediction scale: Top "+str(1))
(max_suc_rate_1,min_suc_rate_1) = cal_rate(max_suc_count_1,min_suc_count_1)
print("Prediction scale: Top "+str(2))
(max_suc_rate_2,min_suc_rate_2) = cal_rate(max_suc_count_2,min_suc_count_2)
print("Prediction scale: Top "+str(3))
(max_suc_rate_3,min_suc_rate_3) = cal_rate(max_suc_count_3,min_suc_count_3)
print("Prediction scale: Top "+str(4))
(max_suc_rate_4,min_suc_rate_4) = cal_rate(max_suc_count_4,min_suc_count_4)
print("Prediction scale: Top "+str(5))
(max_suc_rate_5,min_suc_rate_5) = cal_rate(max_suc_count_5,min_suc_count_5)
# Out:
# Prediction scale: Top 1
# Max prediction success rate:0.9
# Min prediction success rate:0.17
# Prediction scale: Top 2
# Max prediction success rate:0.97
# Min prediction success rate:0.17
# Prediction scale: Top 3
# Max prediction success rate:0.99
# Min prediction success rate:0.17
# Prediction scale: Top 4
# Max prediction success rate:0.99
# Min prediction success rate:0.17
# Prediction scale: Top 5
# Max prediction success rate:0.99
# Min prediction success rate:0.17

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
data = [[1,max_suc_rate_1,min_suc_rate_1], [2,max_suc_rate_2,min_suc_rate_2], [3,max_suc_rate_3,min_suc_rate_3],[4,max_suc_rate_4,min_suc_rate_4], [5,max_suc_rate_5,min_suc_rate_5]]
  
# Create the pandas DataFrame
df = pd.DataFrame(data, columns=['N', 'Max', 'Min'])
print(df)
# Out:
#    N   Max   Min
# 0  1  0.86  0.20
# 1  2  0.97  0.31
# 2  3  0.99  0.47
# 3  4  1.00  0.59
# 4  5  1.00  0.67

# %%
g = sns.lineplot(x='N', y='value', hue='variable', 
             data=pd.melt(df, ['N']),
             )
